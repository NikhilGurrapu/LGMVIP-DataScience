# %% [markdown]
# LetsGrowMore January 2022
#
# Name: Nikhil Gurrapu
#
# Task-2.1: Exploratory Data Analysis on Dataset-Terrorism
#
# Level: Intermediate Level
#
# Language: Python
#
# Dataset Link: https://drive.google.com/file/d/1luTU7xBvI7QAGPbQMxEHcgKUi9d6UeP_/view

# %% [markdown]
# IMPORTING REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv",encoding="latin = 1")
df.head(10)
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# ...

# %%
df.tail(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181681  201712310016   2017      12    31        NaN         0        NaN
# 181682  201712310017   2017      12    31        NaN         0        NaN
# 181683  201712310018   2017      12    31        NaN         0        NaN
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181685  201712310020   2017      12    31        NaN         0        NaN
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.isna().any()
# Out:
# eventid       False
# iyear         False
# imonth        False
# iday          False
# approxdate     True
#               ...
# INT_LOG       False
# INT_IDEO      False
# INT_MISC      False
# INT_ANY       False
# related        True
# Length: 135, dtype: bool

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType',
                   'target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1':'Target_type',
                   'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
df=df[['Year','Month','Day','Country','State','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
df.head(10)
# Out:
#    Year  Month  Day             Country       State  \
# 0  1970      7    2  Dominican Republic         NaN
# 1  1970      0    0              Mexico     Federal
# 2  1970      1    0         Philippines      Tarlac
# 3  1970      1    0              Greece      Attica
# 4  1970      1    0               Japan     Fukouka
# 5  1970      1    1       United States    Illinois
# 6  1970      1    2             Uruguay  Montevideo
# 7  1970      1    2       United States  California
# 8  1970      1    2       United States   Wisconsin
# 9  1970      1    3       United States   Wisconsin
#
#                         Region           city   latitude   longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# ...

# %%
df.corr()
# Out:
#                  Year     Month       Day  latitude  longitude    Killed  \
# Year         1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# Month        0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# Day          0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# latitude     0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# longitude    0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# Killed       0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# Wounded      0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
# Target_type  0.079082 -0.000948 -0.000052 -0.022805  -0.003418  0.008499
#
#               Wounded  Target_type
# Year         0.015273     0.079082
# Month        0.002938    -0.000948
# Day         -0.001268    -0.000052
# latitude     0.015988    -0.022805
# longitude    0.000223    -0.003418
# Killed       0.534375     0.008499
# Wounded      1.000000     0.011303
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
plt.xticks(fontsize=15,rotation=90)
plt.yticks(fontsize=15,rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  [Text(0, 0.5, 'Year'),
#   Text(0, 1.5, 'Month'),
#   Text(0, 2.5, 'Day'),
#   Text(0, 3.5, 'latitude'),
#   Text(0, 4.5, 'longitude'),
#   Text(0, 5.5, 'Killed'),
#   Text(0, 6.5, 'Wounded'),
#   Text(0, 7.5, 'Target_type')])

# %%
df['Country'].value_counts().head(20)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(50,20))
sns.countplot(df['Country'])
plt.title('Country vs Count of Attacks')
plt.xticks(rotation=70,fontsize=12)
plt.yticks(rotation=0,fontsize=12)
plt.xlabel('Country',fontsize=20)
plt.ylabel('No. of Attacks',fontsize=20)
plt.show()
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(50,20))
df['AttackType'].value_counts().plot.bar(color='orange')
plt.title('Most used Attacks',fontsize=25)
plt.xticks(rotation=70,fontsize=15)
plt.yticks(rotation=0,fontsize=15)
plt.xlabel('Attack type Names',fontsize=20)
plt.ylabel('No. of Attack Type',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(40,10))
df['AttackType'].value_counts().head(15).plot.pie()
plt.show()

# %%
plt.figure(figsize=(40,10))
df['Country'].value_counts().tail(15).plot.pie()
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.countplot(df['Region'])
plt.title('Region vs Count of Attacks',fontsize=20)
plt.xticks(rotation=75,fontsize=15)
plt.yticks(rotation=0,fontsize=15)
plt.xlabel('Region',fontsize=15)
plt.ylabel('Attacks',fontsize=15)
plt.show()
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,10))
df['Region'].value_counts().head(15).plot.pie()
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x=df['Year'].value_counts()[:30].index,y=df['Year'].value_counts().values[:30])
plt.title('Number of Attacks per year',fontsize=20)
plt.xticks(rotation=75,fontsize=15)
plt.yticks(rotation=0,fontsize=15)
plt.xlabel('Years',fontsize=15)
plt.ylabel('Attacks',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(30,5))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
df.Killed.plot(kind='line',color='red',label='No. of total fatalty death',linewidth=2,linestyle='--',alpha=1,figsize=(40,10),fontsize=20)
df.Wounded.plot(kind='line',color='green',label='No. of total non-fatal injury',linewidth=2,linestyle='solid',alpha=1,figsize=(40,10),fontsize=20)
plt.legend(loc='upper right',fontsize=25)

# %%
df['Group'].value_counts().head()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Name: Group, dtype: int64

# %%
plt.figure(figsize=(40,20))
sns.countplot(df['Weapon_type'],order=df['Weapon_type'].value_counts().index)
plt.xticks(rotation=50,fontsize=15)
plt.yticks(rotation=0,fontsize=15)
plt.ylabel("No. of attacks",fontsize=20)
plt.xlabel("Weapons",fontsize=20)
plt.show()
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(40,20))
sns.barplot(x=df['Group'].value_counts()[1:20].index,y=df['Group'].value_counts()[1:20])
plt.xticks(rotation=50,fontsize=15)
plt.yticks(rotation=0,fontsize=15)
plt.ylabel("No. of Terrorist ",fontsize=20)
plt.xlabel("Groups",fontsize=20)
plt.title('Number of Terrorists in a Group',fontsize=20)
plt.show()

# %%
pd.crosstab(df.Year,df.Region).plot(kind='line',figsize=(40,10))
plt.grid()
plt.title('Terrorist activities by Region in each Year',fontsize=25)
plt.ylabel("No. of Terrorist ",fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.yticks(rotation=0,fontsize=15)
plt.xticks([1970,1973,1976,1979,1982,1985,1988,1991,1994,1997,2000,2003,2006,2009,2012,2015,2017],rotation=90,fontsize=15)
plt.show()

# %% [markdown]
# Iraq is the Hot Zone of Terrorism

# %% [markdown]
# 2014 was most attacked year by terrorist

# %% [markdown]
# North America and Middle East has the highest no.of attacks

# %% [markdown]
# Explosives weapons was most used
